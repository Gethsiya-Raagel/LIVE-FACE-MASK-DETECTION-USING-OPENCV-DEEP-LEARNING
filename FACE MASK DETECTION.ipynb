# %% [markdown]
# ![Portfolio.jpg](attachment:Portfolio.jpg)

# %% [markdown]
# ![Portfolio2.jpg](attachment:Portfolio2.jpg)

# %% [markdown]
# ![Portfolio3.jpg](attachment:Portfolio3.jpg)

# %% [markdown]
# ![Portfolio4.jpg](attachment:Portfolio4.jpg)

# %% [markdown]
# ![Portfolio5.jpg](attachment:Portfolio5.jpg)

# %% [markdown]
# ![Portfolio6.jpg](attachment:Portfolio6.jpg)
